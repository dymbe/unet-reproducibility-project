# %%
import PIL
from PIL import Image
import numpy 
import elasticdeform
from IPython.display import display

# %%
im = Image.open('data/train-volume.tif')
im_label = Image.open('data/train-labels.tif')
imarray = numpy.array(im)
imarray
# im.show()
# Out:
# array([[126, 107, 122, ..., 161, 164, 177],
#        [138, 118, 123, ..., 153, 149, 153],
#        [141, 135, 145, ..., 144, 145, 137],
#        ...,
#        [155, 149, 168, ..., 139, 115, 120],
#        [163, 154, 166, ..., 158, 141, 148],
#        [151, 141, 160, ..., 183, 164, 171]], dtype=uint8)

# %%
# get the second image of the stack.
im.seek(15)
imarray2 = numpy.array(im)
imarray2[0][0]

# %%
# imarray_deformed = elasticdeform.deform_random_grid(imarray, sigma=25, points=3)
im_deformed = Image.fromarray(imarray_deformed)
im2_def = Image.fromarray(imarray2_deformed)

# %%
[imarr_deformed, imlabelarr_deformed] = elasticdeform.deform_random_grid([numpy.array(im), numpy.array(im_label)])

# %%
display(Image.fromarray(imlabelarr_deformed), Image.fromarray(imarr_deformed))
display(im_label)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F07186297C0>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F0718629DF0>
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=512x512 at 0x7F070F96B400>

# %%
imlabelarray_deformed = elasticdeform.deform_random_grid(imlabelarr, sigma=25, points=3)
im_deformed = Image.fromarray(imarray_deformed)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-7a4df83ebb87> in <module>
# ----> 1 im2.show()
#
# NameError: name 'im2' is not defined
